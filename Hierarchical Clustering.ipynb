# %%
import numpy as np
import pandas as pd

df=pd.read_csv("cardio_preprocessed.csv")
print(df)
# Out:
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0           2     168    62.0    110     80            1     1      0     0
# 1           1     156    85.0    140     90            3     1      0     0
# 2           1     165    64.0    130     70            3     1      0     0
# 3           2     169    82.0    150    100            1     1      0     0
# 4           1     156    56.0    100     60            1     1      0     0
# ...       ...     ...     ...    ...    ...          ...   ...    ...   ...
# 69995       2     168    76.0    120     80            1     1      1     0
# 69996       1     158   126.0    140     90            2     2      0     0
# 69997       2     183   105.0    180     90            3     1      0     1
# 69998       1     163    72.0    135     80            1     2      0     0
# 69999       1     170    72.0    120     80            2     1      0     0
#
#        active  cardio
# 0           1       0
# ...

# %%
df
# Out:
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0           2     168    62.0    110     80            1     1      0     0
# 1           1     156    85.0    140     90            3     1      0     0
# 2           1     165    64.0    130     70            3     1      0     0
# 3           2     169    82.0    150    100            1     1      0     0
# 4           1     156    56.0    100     60            1     1      0     0
# ...       ...     ...     ...    ...    ...          ...   ...    ...   ...
# 69995       2     168    76.0    120     80            1     1      1     0
# 69996       1     158   126.0    140     90            2     2      0     0
# 69997       2     183   105.0    180     90            3     1      0     1
# 69998       1     163    72.0    135     80            1     2      0     0
# 69999       1     170    72.0    120     80            2     1      0     0
#
#        active  cardio
# 0           1       0
# ...

# %%
df.head()
# Out:
#    gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0       2     168    62.0    110     80            1     1      0     0
# 1       1     156    85.0    140     90            3     1      0     0
# 2       1     165    64.0    130     70            3     1      0     0
# 3       2     169    82.0    150    100            1     1      0     0
# 4       1     156    56.0    100     60            1     1      0     0
#
#    active  cardio
# 0       1       0
# 1       1       1
# 2       0       1
# 3       1       1
# 4       0       0

# %%
df.tail()
# Out:
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 69995       2     168    76.0    120     80            1     1      1     0
# 69996       1     158   126.0    140     90            2     2      0     0
# 69997       2     183   105.0    180     90            3     1      0     1
# 69998       1     163    72.0    135     80            1     2      0     0
# 69999       1     170    72.0    120     80            2     1      0     0
#
#        active  cardio
# 69995       1       0
# 69996       1       1
# 69997       0       1
# 69998       0       1
# 69999       1       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   gender       70000 non-null  int64
#  1   height       70000 non-null  int64
#  2   weight       70000 non-null  float64
#  3   ap_hi        70000 non-null  int64
#  4   ap_lo        70000 non-null  int64
#  5   cholesterol  70000 non-null  int64
#  6   gluc         70000 non-null  int64
#  7   smoke        70000 non-null  int64
#  8   alco         70000 non-null  int64
#  9   active       70000 non-null  int64
#  10  cardio       70000 non-null  int64
# dtypes: float64(1), int64(10)
# memory usage: 5.9 MB

# %%
df.describe()
# Out:
#              gender        height        weight         ap_hi         ap_lo  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean       1.349571    164.359229     74.205690    128.817286     96.630414
# std        0.476838      8.210126     14.395757    154.011419    188.472530
# min        1.000000     55.000000     10.000000   -150.000000    -70.000000
# 25%        1.000000    159.000000     65.000000    120.000000     80.000000
# 50%        1.000000    165.000000     72.000000    120.000000     80.000000
# 75%        2.000000    170.000000     82.000000    140.000000     90.000000
# max        2.000000    250.000000    200.000000  16020.000000  11000.000000
#
#         cholesterol          gluc         smoke          alco        active  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean       1.366871      1.226457      0.088129      0.053771      0.803729
# ...

# %%
#Split the dataset x values

# %%
X = df[['gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol', 'gluc', 'smoke', 'alco', 'active' ]][:].values.reshape(70000, 10)
print(X)
# Out:
# [[  2. 168.  62. ...   0.   0.   1.]
#  [  1. 156.  85. ...   0.   0.   1.]
#  [  1. 165.  64. ...   0.   0.   0.]
#  ...
#  [  2. 183. 105. ...   0.   1.   0.]
#  [  1. 163.  72. ...   0.   0.   0.]
#  [  1. 170.  72. ...   0.   0.   1.]]

# %%
Implementing Hierarchical Clustering Algorithm

# %%
from sklearn.cluster import AgglomerativeClustering  

model = AgglomerativeClustering()
model.fit(X)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-6-5795d11eaa92> in <module>
#       2
#       3 model = AgglomerativeClustering()
# ----> 4 model.fit(X)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\_agglomerative.py in fit(self, X, y)
#     857                                          n_clusters=n_clusters,
#     858                                          return_distance=return_distance,
# --> 859                                          **kwargs)
#     860         (self.children_,
#     861          self.n_connected_components_,
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\memory.py in __call__(self, *args, **kwargs)
#     353
#     354     def __call__(self, *args, **kwargs):
# --> 355         return self.func(*args, **kwargs)
#     356
#     357     def call_and_shelve(self, *args, **kwargs):
#
# ...
